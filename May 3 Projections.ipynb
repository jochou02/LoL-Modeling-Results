# %%
from helper import *
pd.set_option('display.precision', 2)

import warnings
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

from ipynb.fs.full.functions import project

# %%
file = 'Testing/May 3.csv'

# %%
favorites = pd.DataFrame()

# %% [markdown]
# # BO3s

# %%
df = pd.read_csv(file)
df = df[df['Stat type'] == 'MAPS 1-2 Kills'].sort_values('Team').drop(['Added', 'Updated'], axis=1)
df
# Out:
#         Name Position Team Opponent Team       Stat type  Projection
# 0        Elk      BOT  BLG            R7  MAPS 1-2 Kills        13.0
# 7      Yagao      MID  BLG            R7  MAPS 1-2 Kills         8.5
# 8        Xun      JNG  BLG            R7  MAPS 1-2 Kills         8.0
# 22       Bin      TOP  BLG            R7  MAPS 1-2 Kills         8.0
# 2       Kati      MID  GAM            GG  MAPS 1-2 Kills         4.5
# 21      Levi      JNG  GAM            GG  MAPS 1-2 Kills         6.0
# 24     Kiaya      TOP  GAM            GG  MAPS 1-2 Kills         5.0
# 28     Sty1e      BOT  GAM            GG  MAPS 1-2 Kills         7.5
# 4    Stixxay      BOT   GG           GAM  MAPS 1-2 Kills        12.0
# 13      Gori      MID   GG           GAM  MAPS 1-2 Kills         8.0
# 15     River      JNG   GG           GAM  MAPS 1-2 Kills         5.5
# 17  Licorice      TOP   GG           GAM  MAPS 1-2 Kills         5.0
# 10       Ceo      BOT   R7           BLG  MAPS 1-2 Kills         4.0
# 19     Mireu      MID   R7           BLG  MAPS 1-2 Kills         4.0
# 26     Oddie      JNG   R7           BLG  MAPS 1-2 Kills         3.0
# 30      Bong      TOP   R7           BLG  MAPS 1-2 Kills         2.0

# %%
proj = project('BLG', 'R7', 2, 0, df)
favorites = favorites.append(proj)
# Out:
#     Name Position Team Opponent Team       Stat type  Projection  Model Proj  \
# 0    Elk      BOT  BLG            R7  MAPS 1-2 Kills        13.0       13.35
# 1  Yagao      MID  BLG            R7  MAPS 1-2 Kills         8.5        7.45
# 2    Xun      JNG  BLG            R7  MAPS 1-2 Kills         8.0        7.00
# 3    Bin      TOP  BLG            R7  MAPS 1-2 Kills         8.0        5.95
# 4    Ceo      BOT   R7           BLG  MAPS 1-2 Kills         4.0        4.80
# 5  Mireu      MID   R7           BLG  MAPS 1-2 Kills         4.0        6.67
# 6  Oddie      JNG   R7           BLG  MAPS 1-2 Kills         3.0        3.87
# 7   Bong      TOP   R7           BLG  MAPS 1-2 Kills         2.0        2.00
#
#    Difference
# 0        0.35
# 1       -1.05
# 2       -1.00
# 3       -2.05
# 4        0.80
# 5        2.67
# 6        0.87
# 7        0.00
# PROJECTIONS BASED ON: BLG 2-0 R7

# %%
proj = project('GG', 'GAM', 2, 0, df)
favorites = favorites.append(proj)
# Out:
#        Name Position Team Opponent Team       Stat type  Projection  \
# 0   Stixxay      BOT   GG           GAM  MAPS 1-2 Kills        12.0
# 1      Gori      MID   GG           GAM  MAPS 1-2 Kills         8.0
# 2     River      JNG   GG           GAM  MAPS 1-2 Kills         5.5
# 3  Licorice      TOP   GG           GAM  MAPS 1-2 Kills         5.0
# 4      Kati      MID  GAM            GG  MAPS 1-2 Kills         4.5
# 5      Levi      JNG  GAM            GG  MAPS 1-2 Kills         6.0
# 6     Kiaya      TOP  GAM            GG  MAPS 1-2 Kills         5.0
# 7     Sty1e      BOT  GAM            GG  MAPS 1-2 Kills         7.5
#
#    Model Proj  Difference
# 0       12.95        0.95
# 1        7.58       -0.42
# 2        4.95       -0.55
# 3        5.37        0.37
# 4        6.17        1.67
# 5        5.50       -0.50
# 6        5.83        0.83
# 7        6.00       -1.50
# PROJECTIONS BASED ON: GG 2-0 GAM

# %% [markdown]
# # Favorite Plays

# %%
favorites
# Out:
#     Name Position Team Opponent Team       Stat type  Projection  Model Proj  \
# 3    Bin      TOP  BLG            R7  MAPS 1-2 Kills         8.0        5.95
# 5  Mireu      MID   R7           BLG  MAPS 1-2 Kills         4.0        6.67
# 4   Kati      MID  GAM            GG  MAPS 1-2 Kills         4.5        6.17
# 7  Sty1e      BOT  GAM            GG  MAPS 1-2 Kills         7.5        6.00
#
#    Difference
# 3       -2.05
# 5        2.67
# 4        1.67
# 7       -1.50
