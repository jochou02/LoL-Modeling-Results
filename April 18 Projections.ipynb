# %%
from helper import *
pd.set_option('display.precision', 2)

import warnings
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

from ipynb.fs.full.functions import project

# %%
file = 'Testing/April 18.csv'

# %%
favorites = pd.DataFrame()

# %% [markdown]
# # BO5s

# %%
df = pd.read_csv(file)
df = df[df['Stat type'] == 'MAPS 1-3 Kills'].sort_values('Team').drop(['Added', 'Updated'], axis=1)
df
# Out:
#         Name Position  Team Opponent Team       Stat type  Projection
# 11   Destroy      TOP    IW          LDLC  MAPS 1-3 Kills         9.0
# 30       BAO      BOT    IW          LDLC  MAPS 1-3 Kills        15.0
# 33   Elramir      JNG    IW          LDLC  MAPS 1-3 Kills         8.0
# 42     Kofte      MID    IW          LDLC  MAPS 1-3 Kills        11.0
# 2     Jeskla      BOT  LDLC            IW  MAPS 1-3 Kills        13.5
# 5      White      JNG  LDLC            IW  MAPS 1-3 Kills         6.0
# 8      Kryze      TOP  LDLC            IW  MAPS 1-3 Kills         8.0
# 47  Backlund      MID  LDLC            IW  MAPS 1-3 Kills        13.0
# 13       Vzz      BOT   MCK           SKP  MAPS 1-3 Kills        13.0
# 22       ACD      TOP   MCK           SKP  MAPS 1-3 Kills         8.5
# 38     Six10      MID   MCK           SKP  MAPS 1-3 Kills         9.0
# 40      Cboi      JNG   MCK           SKP  MAPS 1-3 Kills         5.5
# 15   FEBIVEN      MID   SKP           MCK  MAPS 1-3 Kills        10.5
# 19       JNX      TOP   SKP           MCK  MAPS 1-3 Kills         9.0
# 26     Lurox      JNG   SKP           MCK  MAPS 1-3 Kills        11.5
# 28    Keduii      BOT   SKP           MCK  MAPS 1-3 Kills        16.5

# %%
proj = project('IW', 'LDLC', 2, 1, df)
favorites = favorites.append(proj)
# Out:
#        Name Position  Team Opponent Team       Stat type  Projection  \
# 0   Destroy      TOP    IW          LDLC  MAPS 1-3 Kills         9.0
# 1       BAO      BOT    IW          LDLC  MAPS 1-3 Kills        15.0
# 2   Elramir      JNG    IW          LDLC  MAPS 1-3 Kills         8.0
# 3     Kofte      MID    IW          LDLC  MAPS 1-3 Kills        11.0
# 4    Jeskla      BOT  LDLC            IW  MAPS 1-3 Kills        13.5
# 5     White      JNG  LDLC            IW  MAPS 1-3 Kills         6.0
# 6     Kryze      TOP  LDLC            IW  MAPS 1-3 Kills         8.0
# 7  Backlund      MID  LDLC            IW  MAPS 1-3 Kills        13.0
#
#    Model Proj  Difference
# 0       10.49        1.49
# 1       17.04        2.04
# 2        7.91       -0.09
# 3       12.33        1.33
# 4        9.97       -3.53
# 5        4.09       -1.91
# 6        5.58       -2.42
# 7       11.04       -1.96
# PROJECTIONS BASED ON: IW 2-1 LDLC

# %%
proj = project('SKP', 'MCK', 2, 1, df)
favorites = favorites.append(proj)
# Out:
#       Name Position Team Opponent Team       Stat type  Projection  \
# 0  FEBIVEN      MID  SKP           MCK  MAPS 1-3 Kills        10.5
# 1      JNX      TOP  SKP           MCK  MAPS 1-3 Kills         9.0
# 2    Lurox      JNG  SKP           MCK  MAPS 1-3 Kills        11.5
# 3   Keduii      BOT  SKP           MCK  MAPS 1-3 Kills        16.5
# 4      Vzz      BOT  MCK           SKP  MAPS 1-3 Kills        13.0
# 5      ACD      TOP  MCK           SKP  MAPS 1-3 Kills         8.5
# 6    Six10      MID  MCK           SKP  MAPS 1-3 Kills         9.0
# 7     Cboi      JNG  MCK           SKP  MAPS 1-3 Kills         5.5
#
#    Model Proj  Difference
# 0       10.93        0.43
# 1        8.87       -0.13
# 2        9.36       -2.14
# 3       16.30       -0.20
# 4       14.61        1.61
# 5        6.39       -2.11
# 6        9.57        0.57
# 7        7.04        1.54
# PROJECTIONS BASED ON: SKP 2-1 MCK

# %% [markdown]
# # Favorite Plays

# %%
favorites
# Out:
#        Name Position  Team Opponent Team       Stat type  Projection  \
# 1       BAO      BOT    IW          LDLC  MAPS 1-3 Kills        15.0
# 4    Jeskla      BOT  LDLC            IW  MAPS 1-3 Kills        13.5
# 5     White      JNG  LDLC            IW  MAPS 1-3 Kills         6.0
# 6     Kryze      TOP  LDLC            IW  MAPS 1-3 Kills         8.0
# 7  Backlund      MID  LDLC            IW  MAPS 1-3 Kills        13.0
# 2     Lurox      JNG   SKP           MCK  MAPS 1-3 Kills        11.5
# 4       Vzz      BOT   MCK           SKP  MAPS 1-3 Kills        13.0
# 5       ACD      TOP   MCK           SKP  MAPS 1-3 Kills         8.5
# 7      Cboi      JNG   MCK           SKP  MAPS 1-3 Kills         5.5
#
#    Model Proj  Difference
# 1       17.04        2.04
# 4        9.97       -3.53
# 5        4.09       -1.91
# 6        5.58       -2.42
# 7       11.04       -1.96
# 2        9.36       -2.14
# 4       14.61        1.61
# 5        6.39       -2.11
# 7        7.04        1.54
